# %%
import xml.etree.ElementTree as ET
from pathlib import Path
import shutil
import typing
from borb.pdf import Document, PDF
import os
from tkinter import *
from tkinter import ttk
from tkinter import filedialog
from tkinter import messagebox
import threading
import zipfile
from fillpdf import fillpdfs
# from borb.pdf import Table, TableCell
# from borb.pdf import Paragraph
# from borb.pdf import SingleColumnLayoutWithOverflow
# from borb.pdf import PageLayout
# from borb.pdf.canvas.geometry.rectangle import Rectangle
# from decimal import Decimal


class Xml_a_pdf:
    def __init__(self, root):
        self.root = root
        
        self.archivosXML = []
        
        self.errores = []
        
        self.carpeta_destino = ""
        
        self.numerosTexto = {
            '32.00': 'Son: Treinta y dos con 00/100. Soles',
            '30.70': 'Son: Treinta con 70/100. Soles',
            '28.00': 'Son: Veintiocho con 00/100. Soles',
            '26.90': 'Son: Veintiséis con 90/100. Soles',
            '23.10': 'Son: Veintitrés con 10/100. Soles',
            '20.00': 'Son: Veinte con 00/100. Soles',
            '19.20': 'Son: Diesinueve con 20/100. Soles',
            '16.00': 'Son: Dieciséis con 00/100. Soles',
            '15.40': 'Son: Quince con 40/100. Soles',
            '12.00': 'Son: Doce con 00/100. Soles',
            '11.60': 'Son: Once con 60/100. Soles',
            '8.00': 'Son: Ocho con 00/100. Soles',
            '7.70': 'Son: Siete con 70/100. Soles',
            '5.00': 'Son: Cinco con 00/100. Soles',
            '3.90': 'Son: Tres con 90/100. Soles',
            '1.20': 'Son: Uno con 20/100. Soles',
            '0.60': 'Son: Cero con 60/100. Soles'
        }
        
        # Variable para almacenar el progreso de la barra de carga General
        self.progresoGeneral = 0
        
        # Variable para almacenar el total de la barra de carga
        self.total = 0
        
        self.datos_formulario = {}
        
        self.peaje_nombres = {
            '1': 'Matarani',
            '2': 'Uchumayo',
            '3': 'Unidad de Peaje Patahuasi km 78+200 Ruta 30B',
            '4': 'Unidad de Peaje Santa Lucia km 201+700 Ruta 30B',
            '5': 'Illpa',
            '6': 'Unidad de Peaje Pampa Cuellar km 65+000 Ruta 34A',
            '7': 'Ilo'
        }
        
        ## Configuracion TKinter
        
        self.root.title("Convertir XML a PDF")
        self.root.resizable(FALSE, FALSE)
        
        # Especificar el tamaño de la ventana
        ancho_ventana = 350
        alto_ventana = 400

        # Configuración del mainframe
        mainframe = ttk.Frame(self.root, width=ancho_ventana, height=alto_ventana, padding="3 3 12 12")
        mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        
        # Añadir los widgets a utilizar y ubicarlos en el grid
        lblArchivoXML = ttk.Label(mainframe, text="Selecciona los archivos XML:", wraplength=100)
        
        self.btnSeleccionarXML = ttk.Button(mainframe, text="Seleccionar XML", command=self.seleccionarCarpeta_o_ArchivosXML)
        
        # Variable para almacenar estado de archivo seleccionado
        self.estaSeleccionadoXML = StringVar()
        self.estaSeleccionadoXML.set("")
        self.lblCargadosXML = ttk.Label(mainframe, textvariable=self.estaSeleccionadoXML, wraplength=100)
        
        # Vincular función para verificar cambios
        self.estaSeleccionadoXML.trace_add("write", self.escuchar_cambios_seleccionado)
        
        self.btnConvertir = ttk.Button(mainframe, text="Convertir", command=self.btnConvertir_handler)
        btnCerrar = ttk.Button(mainframe, text="Cerrar Programa", command=self.cerrarPrograma)
        
        # Configuracion grid
        lblArchivoXML.grid(column=0, row=0)
        self.btnSeleccionarXML.grid(column=1, row=0)
        self.lblCargadosXML.grid(column=2, row=0)
        self.btnConvertir.grid(column=1,row=1)
        btnCerrar.grid(column=1, row=2)
        
        # Cambiar estados a desabilitados
        self.btnConvertir.state(['disabled'])
        
        # Barra de progreso
        self.progreso = ttk.Progressbar(mainframe, orient="horizontal", mode="determinate")
        self.progreso.grid(column=0, row=3, sticky="nswe", columnspan=3)

        # Etiqueta que muestra el progreso en texto
        self.label_progreso = ttk.Label(mainframe, text="Progreso: 0%")
        self.label_progreso.grid(column=1, row=4, sticky="ns")
        
        # Centra ventana al abrir programa
        self.centrar_ventana(self.root, ancho_ventana, alto_ventana)
        
        # Configura el peso del programa padre para que se amplie con la ventana
        self.root.columnconfigure(0, weight=1)
        self.root.rowconfigure(0, weight=1)
        
        # Asigna los pesos para que se amplien con la ventana
        mainframe.columnconfigure(0, weight=1, uniform="col")
        mainframe.columnconfigure(1, weight=1, uniform="col")
        mainframe.columnconfigure(2, weight=1, uniform="col")
        
        mainframe.rowconfigure(0, weight=1)
        mainframe.rowconfigure(1, weight=1)
        mainframe.rowconfigure(2, weight=1)
        mainframe.rowconfigure(3, weight=1)
        mainframe.rowconfigure(4, weight=1)
        
        # Loop para dar padding a todos los widgets hijos
        for child in mainframe.winfo_children(): 
            child.grid_configure(padx=5, pady=5)
    
    def cerrarPrograma(self):
        self.root.destroy() 
    
    # Función para que la ventana principal (self.root) se abra en el centro de la pantalla
    def centrar_ventana(self, ventana, ancho, alto):
        # Obtener el ancho y alto de la pantalla
        ancho_pantalla = ventana.winfo_screenwidth()
        alto_pantalla = ventana.winfo_screenheight()

        # Calcular las coordenadas x, y para centrar la ventana
        x = (ancho_pantalla // 2) - (ancho // 2)
        y = (alto_pantalla // 2) - (alto // 2)

        # Fijar las dimensiones y la posición de la ventana
        ventana.geometry(f'{ancho}x{alto}+{x}+{y}')
    
    # Función para actualizar barra de progreso    
    def actualizar_progresoGeneral(self, total):
        ## Actualizar barra de progreso
        # aumentar en 1 el progreso
        self.progresoGeneral += 1
        
        # Actualizar la barra de progreso
        self.progreso["value"] = self.progresoGeneral  # Actualizar el valor de la barra
        self.label_progreso.config(text=f"Progreso: {int((self.progresoGeneral) / total * 100)}%")

        # Actualizar la interfaz gráfica
        self.root.update_idletasks() 
    
    # Función para reiniciar el progreso de la barra General       
    def reiniciar_progresoGeneral(self):
        self.carpeta_destino = ""
        # Reiniciar la variable de progresoGeneral
        self.progresoGeneral = 0
        # Actualizar la barra de progreso
        self.progreso["value"] = self.progresoGeneral  # Actualizar el valor de la barra
        self.label_progreso.config(text="Progreso: 0%")
    
    # Verificar cambios self.estan_cagados
    def escuchar_cambios_seleccionado(self, *args):
        estaSeleccionadoXML = self.estaSeleccionadoXML.get()
        if estaSeleccionadoXML != "" and estaSeleccionadoXML != "No se seleccionó archivo" :
            self.btnConvertir.state(['!disabled'])
        else:
            self.btnConvertir.state(['disabled'])

    # Función para abrir ventana emergente para seleccionar los archivos
    def seleccionarCarpeta_o_ArchivosXML(self):
        
        # Preguntar al usuario si quiere seleccionar una carpeta o archivos
        opcion = messagebox.askquestion(
            "Seleccionar",
            "¿Deseas seleccionar XML de una carpeta o archivos separados?",
            icon="question"
        )
        
        # Seleccionar archivos XML o carpeta según la respuesta del usuario
        if opcion == "yes":  # Si elige 'Sí', selecciona una carpeta
            # Abrir ventana para seleccionar carpeta
            carpeta = filedialog.askdirectory(title="Seleccionar carpeta")
            
            # Comprobar si se ha seleccionado una carpeta
            if carpeta:
                carpeta_path = Path(carpeta)
                self.carpeta_destino = f"./Reportes/{carpeta_path.name}"
                
                # Guardar todos los archivos XML en un array
                self.archivosXML = [archivo for archivo in carpeta_path.glob("*.xml") if not archivo.name.startswith("R-")]
                
                if self.archivosXML:
                    # Cambiar color al label a negro en caso de que este en rojo
                    self.lblCargadosXML.config(foreground="black")
                    
                    print("Archivos seleccionados:", len(self.archivosXML))
                    
                    # Cambiar el valor de la etiqueta a 'estaSeleccionado'
                    self.estaSeleccionadoXML.set(f"Archivos Seleccionados: {len(self.archivosXML)} archivos")
                else:
                    self.estaSeleccionadoXML.set("No se encontraron archivos XML en la carpeta seleccionada")
                    self.lblCargadosXML.config(foreground="red")
            else:
                self.estaSeleccionadoXML.set("No se seleccionó ninguna carpeta")
                self.lblCargadosXML.config(foreground="red")
        else:
        
            # Abrir ventana emergente para seleccionar los archivos excel a subir
            self.archivosXML = filedialog.askopenfilenames(filetypes=[("Archivos XML", "*.xml")])
            
            # Comprobar si se han seleccionado archivos
            if self.archivosXML:
            
                if len(self.archivosXML) == 1:
                    archivosXML = Path(self.archivosXML[0])
                    
                    # Cambiar color al label a negro en caso de que este en rojo
                    self.lblCargadosXML.config(foreground="black")
                    
                    print("Archivos seleccionados:", self.archivosXML)
                    
                    # Cambiar el valor de la etiqueta a 'estaSeleccionado'
                    self.estaSeleccionadoXML.set(f"Archivo Seleccionado: {archivosXML.stem} ")
                
                else:
                    # Cambiar color al label a negro en caso de que este en rojo
                    self.lblCargadosXML.config(foreground="black")
                    
                    print("Archivos seleccionados:", self.archivosXML)
                    
                    # Cambiar el valor de la etiqueta a 'estaSeleccionado'
                    self.estaSeleccionadoXML.set(f"Archivos Seleccionados: {len(self.archivosXML)} archivos")
                    
            else:
                self.estaSeleccionadoXML.set("No se seleccionó archivo")
                self.lblCargadosXML.config(foreground="red")
    
    def btnConvertir_handler(self):
        # Limpiar diccionario
        self.datos_formulario.clear()
        self.reiniciar_progresoGeneral()
        
        # Ejecutar la carga de data en un hilo separado
        threading.Thread(target=self.convertir).start()

    def convertir(self):
        
        self.total = len(self.archivosXML)*2
        self.progreso["maximum"] = self.total
        
        for archivo in self.archivosXML:
            
            nombreArchivo = Path(archivo).stem
        
            tipoDoc = self.leer_XML(archivo)
            
            self.actualizar_progresoGeneral(self.total)
            
            # Verifica el tipo de documento y escoge la plantilla más apropiada
            match str(tipoDoc):
                case '01':
                    # Si nota_detracciones es diferente a '0' entonces escoge la plantilla 1
                    if self.datos_formulario['nota_detracciones'] != '0':
                        plantilla = 'plantillaFactura1.pdf'
                    else:
                        plantilla = 'plantillaFactura2.pdf'
                case '03':
                    plantilla = 'plantillaBoleta.pdf'
                case '07':
                    plantilla = 'plantillaNotaCredito.pdf'
                case '08':
                    plantilla = 'plantillaNotaDebito.pdf'
            
            self.rellenar_plantilla(plantilla, self.datos_formulario, nombreArchivo, tipoDoc)
            self.actualizar_progresoGeneral(self.total)
            
        if len(self.archivosXML) == 1:
            # Abrir ventana para abrir carpeta
            self.ventana_carpeta_generada(f'./Reportes/{nombreArchivo}/')
        else:
            self.ventana_carpeta_generada('./Reportes/')
        
        self.btnConvertir.state(['!disabled'])
        
        if self.errores:
            print(f"Hubo errores en los archivos: ")
            for e in self.errores:
                print("\n")
                print(e)

    # Función para copiar y luego rellenar el PDF
    def rellenar_plantilla(self, plantilla, datos_formulario, nombreArchivo, tipoDoc):
        try:
            self.carpeta_destino = f'./Reportes/{nombreArchivo}' if self.carpeta_destino == "" else self.carpeta_destino
            # Verificar si la carpeta de destino existe, si no, crearla
            if not os.path.exists(self.carpeta_destino):
                os.makedirs(self.carpeta_destino)

            # Crear la ruta completa del archivo con el nombre personalizado
            archivo_destino = Path(self.carpeta_destino) / f"{nombreArchivo}.pdf"
            
            if not archivo_destino.exists():

                form_fields = list(fillpdfs.get_form_fields(f'./plantillas/{plantilla}').keys())

                match tipoDoc:
                    case '01':
                        if datos_formulario['nota_detracciones'] != '0':
                            
                            if datos_formulario['comentario'] != '0':
                                observacion =  datos_formulario['comentario']
                            else:
                                observacion = datos_formulario['observacion']
                                    
                            data_dict = {
                                # Rellenar los campos del formulario en la copia
                                form_fields[2]: datos_formulario['doc'],
                                form_fields[0]: datos_formulario['nombre'],
                                form_fields[3]: datos_formulario['fecha'],
                                form_fields[1]: datos_formulario['documento'],
                                form_fields[24]: datos_formulario['direccion'],
                                form_fields[4]: datos_formulario['forma_pago'],
                                form_fields[6]: datos_formulario['item'],
                                form_fields[8]: datos_formulario['codigo'],
                                form_fields[7]: datos_formulario['descripcion'],
                                form_fields[5]: datos_formulario['und'],
                                form_fields[9]: datos_formulario['cantidad'],
                                form_fields[10]: datos_formulario['vUnitario'],
                                form_fields[11]: datos_formulario['pUnitario'],
                                form_fields[12]: datos_formulario['valorV'],
                                form_fields[22]: datos_formulario['numeroTexto'],
                                form_fields[14]: datos_formulario['opGravada'],
                                form_fields[15]: datos_formulario['igv'],
                                form_fields[13]: datos_formulario['total'],
                                form_fields[16]: datos_formulario['observacionesSunat'],
                                form_fields[18]: datos_formulario['direccionSucursal'],
                                form_fields[19]: datos_formulario['nota_detracciones'],
                                form_fields[17]: observacion,
                                form_fields[20]: datos_formulario['placa'],
                                form_fields[21]: datos_formulario['hash'],
                                form_fields[23]: datos_formulario['ruc'],
                            }
                            
                        else:
                            if datos_formulario['comentario'] != '0':
                                observacion = datos_formulario['comentario']
                            else:
                                observacion = datos_formulario['observacion'],
                            # Rellenar los campos del formulario en la copia
                            data_dict = {
                                form_fields[2]: datos_formulario['doc'],
                                form_fields[0]: datos_formulario['nombre'],
                                form_fields[3]: datos_formulario['fecha'],
                                form_fields[23]: datos_formulario['documento'],
                                form_fields[1]: datos_formulario['direccion'],
                                form_fields[4]: datos_formulario['forma_pago'],
                                form_fields[6]: datos_formulario['item'],
                                form_fields[8]: datos_formulario['codigo'],
                                form_fields[7]: datos_formulario['descripcion'],
                                form_fields[5]: datos_formulario['und'],
                                form_fields[9]: datos_formulario['cantidad'],
                                form_fields[10]: datos_formulario['vUnitario'],
                                form_fields[11]: datos_formulario['pUnitario'],
                                form_fields[12]: datos_formulario['valorV'],
                                form_fields[21]: datos_formulario['numeroTexto'],
                                form_fields[14]: datos_formulario['opGravada'],
                                form_fields[15]: datos_formulario['igv'],
                                form_fields[13]: datos_formulario['total'],
                                form_fields[16]: datos_formulario['observacionesSunat'],
                                form_fields[18]: datos_formulario['direccionSucursal'],
                                form_fields[17]: observacion,
                                form_fields[19]: datos_formulario['placa'],
                                form_fields[20]: datos_formulario['hash'],
                                form_fields[22]: datos_formulario['ruc']
                            }
                            
                    case '03':
                        data_dict = {
                            form_fields[13]: datos_formulario['doc'],
                            form_fields[0]: datos_formulario['nombre'],
                            form_fields[21]: datos_formulario['fecha'],
                            form_fields[1]: datos_formulario['documento'],
                            form_fields[2]: datos_formulario['item'],
                            form_fields[3]: datos_formulario['codigo'],
                            form_fields[4]: datos_formulario['descripcion'],
                            form_fields[5]: datos_formulario['und'],
                            form_fields[6]: datos_formulario['cantidad'],
                            form_fields[8]: datos_formulario['vUnitario'],
                            form_fields[7]: datos_formulario['pUnitario'],
                            form_fields[10]: datos_formulario['valorV'],
                            form_fields[18]: datos_formulario['numeroTexto'],
                            form_fields[9]: datos_formulario['opGravada'],
                            form_fields[12]: datos_formulario['igv'],
                            form_fields[11]: datos_formulario['total'],
                            form_fields[14]: datos_formulario['observacionesSunat'],
                            form_fields[15]: datos_formulario['direccionSucursal'],
                            form_fields[16]: datos_formulario['observacion'],
                            form_fields[17]: datos_formulario['placa'],
                            form_fields[19]: datos_formulario['hash'],
                            form_fields[20]: datos_formulario['ruc'],
                        }
                    case '07':
                        data_dict = {
                            form_fields[13]: datos_formulario['doc'],
                            form_fields[0]: datos_formulario['nombre'],
                            form_fields[18]: datos_formulario['fecha'],
                            form_fields[21]: datos_formulario['documento'],
                            form_fields[1]: datos_formulario['direccion'],
                            form_fields[19]: datos_formulario['documento_referencia'],
                            form_fields[2]: datos_formulario['item'],
                            form_fields[3]: datos_formulario['codigo'],
                            form_fields[4]: datos_formulario['descripcion'],
                            form_fields[5]: datos_formulario['und'],
                            form_fields[6]: datos_formulario['cantidad'],
                            form_fields[8]: datos_formulario['vUnitario'],
                            form_fields[7]: datos_formulario['pUnitario'],
                            form_fields[10]: datos_formulario['valorV'],
                            form_fields[20]: datos_formulario['numeroTexto'],
                            form_fields[9]: datos_formulario['opGravada'],
                            form_fields[12]: datos_formulario['igv'],
                            form_fields[11]: datos_formulario['total'],
                            form_fields[14]: datos_formulario['observacionesSunat'],
                            form_fields[15]: datos_formulario['motivo'],
                            form_fields[16]: datos_formulario['hash'],
                            form_fields[17]: datos_formulario['ruc'],
                        }
                    case '08':
                        data_dict = {
                            form_fields[13]: datos_formulario['doc'],
                            form_fields[0]: datos_formulario['nombre'],
                            form_fields[18]: datos_formulario['fecha'],
                            form_fields[21]: datos_formulario['documento'],
                            form_fields[1]: datos_formulario['direccion'],
                            form_fields[19]: datos_formulario['documento_referencia'],
                            form_fields[2]: datos_formulario['item'],
                            form_fields[3]: datos_formulario['codigo'],
                            form_fields[4]: datos_formulario['descripcion'],
                            form_fields[5]: datos_formulario['und'],
                            form_fields[6]: datos_formulario['cantidad'],
                            form_fields[8]: datos_formulario['vUnitario'],
                            form_fields[7]: datos_formulario['pUnitario'],
                            form_fields[10]: datos_formulario['valorV'],
                            form_fields[20]: datos_formulario['numeroTexto'],
                            form_fields[9]: datos_formulario['opGravada'],
                            form_fields[12]: datos_formulario['igv'],
                            form_fields[11]: datos_formulario['total'],
                            form_fields[14]: datos_formulario['observacionesSunat'],
                            form_fields[15]: datos_formulario['motivo'],
                            form_fields[16]: datos_formulario['hash'],
                            form_fields[17]: datos_formulario['ruc']
                        }
                
                # Guardar el PDF rellenado
                fillpdfs.write_fillable_pdf( input_pdf_path= f'./plantillas/{plantilla}', output_pdf_path=archivo_destino, data_dict=data_dict, flatten=True)
                
        except Exception as e:
            print(f"Error en el archivo: {nombreArchivo}")
            print(e)
            
            self.errores.append(nombreArchivo)
        
    
    def leer_XML(self, archivo):
        tree = ET.parse(archivo)
        root = tree.getroot()
        
        namespaces = {
            'cac': "urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2",
            'cbc': "urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2",
        }
        
        # Verificar si existe el elemento cac:DiscrepancyResponse para saber si el documento
        # es nota de debito o credito
        discrepancy_response = root.find('cac:DiscrepancyResponse', namespaces)
        tipoDoc = root.find('cbc:InvoiceTypeCode', namespaces)
        
        try:

            # Comprobar si el elemento existe
            if discrepancy_response is not None:
                # Buscar el elemento ResponseCode dentro del nodo DiscrepancyResponse
                response_code = root.find('cac:DiscrepancyResponse//cbc:ResponseCode', namespaces)
                # Acceder al atributo listName
                list_name = response_code.attrib.get('listName')
                print(f"listName: {list_name}")
                if list_name in ['Tipo de nota de debito', 'Tipo de nota de débito']:
                    # Asignar el tipo de documento para el procesado
                    tipoDoc = '08'
                elif list_name in ['Tipo de nota de credito', 'Tipo de nota de crédito']:
                    tipoDoc = '07'
            if tipoDoc is not None:
                tipoDoc = tipoDoc.text
            else:    
                tipoDoc = root.find('.//cbc:DocumentTypeCode', namespaces).text
                
            match tipoDoc:
                case '01':
                    self.procesar_factura(root, archivo)
                case '03':
                    self.procesar_boleta(root, archivo)
                case '07':
                    self.procesar_nota_credito(root, archivo)
                case '08':
                    self.procesar_nota_debito(root, archivo)
            
            return tipoDoc
    
        except Exception as e:
            print(f"Ocurrio un error al leer el archivo {archivo}")
            self.errores.append(archivo)
    
    def procesar_nota_debito(self, root, archivo):
        # Definir el namespace para cbc y cac
        namespaces = {
            'xmlns': "urn:oasis:names:specification:ubl:schema:xsd:DebitNote-2",
            'biz': "urn:bizlinks:names:specification:ubl:peru:schema:xsd:BizlinksAggregateComponents-1",
            'cac': "urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2",
            'cbc': "urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2",
            'ds': "http://www.w3.org/2000/09/xmldsig#",
            'ext': "urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
            'qdt': "urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
            'sac': "urn:sunat:names:specification:ubl:peru:schema:xsd:SunatAggregateComponents-1"
        }
        # Fecha y Hora
        date = root.find("cbc:IssueDate", namespaces).text
        time = root.find("cbc:IssueTime", namespaces).text
        # datetime.strptime(date.text, '%Y-%m-%d')
        fechaEmision = f"{date} {time}"
        print(f"Fecha emision: {fechaEmision}")

        # Código Hash
        hash = root.find('.//ds:DigestValue', namespaces).text
        print(f"hash: {hash}")

        # Nombre
        ## Buscar el valor de cbc:RegistrationName dentro de cac:AccountingCustomerParty
        nombre = root.find('.//cac:AccountingCustomerParty//cbc:RegistrationName', namespaces).text

        print(f'nombre: {nombre}') 
        
            
        # DNI
        documento = root.find('.//cac:AccountingCustomerParty//cbc:ID', namespaces).text
        print (f'documento: {documento}')
        doc = root.find('cbc:ID', namespaces)
        doc = doc.text
        print(f'doc: {doc}')
        
        # MOTIVO
        motivo = root.find('cac:DiscrepancyResponse//cbc:Description', namespaces).text
        print(f'motivo: {motivo}')
        
        #DOCUMENTO REFERENCIA
        documento_referencia = root.find('cac:BillingReference//cbc:ID', namespaces).text
        print(f'documento_referencia: {documento_referencia}')
        
        # Direccion
        direccion = root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces).text if root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces) is not None else '-'
        print(f'direccion: {direccion}')
        
        # Items
        ## Item
        item = root.find('.//cac:DebitNoteLine//cbc:ID', namespaces).text
        print(item)

        ## Código
        codigo = root.find('.//cac:DebitNoteLine//cac:Item//cbc:ID', namespaces)
        codigo = codigo.text if codigo is not None else item
        print(codigo)

        ## Descripción
        desc = root.find('.//cac:DebitNoteLine//cac:Item//cbc:Description', namespaces).text

        ## Und.
        und = root.find('.//cac:DebitNoteLine//cbc:DebitedQuantity', namespaces)
        und = und.attrib.get('unitCode')
        print(f'und: {und}')

        ## Cantidad
        cantidad = root.find('.//cac:DebitNoteLine//cbc:DebitedQuantity', namespaces).text
        cantidad = format(float(cantidad), '.2f')
        print(f'cantidad: {cantidad}')

        ## V. Unitario
        vUnitario = root.find('.//cac:DebitNoteLine//cbc:LineExtensionAmount', namespaces).text
        vUnitario = format(float(vUnitario), '.4f')
        print(f'vUnitario: {vUnitario}')

        ## P. Unitario
        pUnitario = root.find('.//cac:DebitNoteLine//cac:PricingReference//cbc:PriceAmount', namespaces).text
        pUnitario = format(float(pUnitario), '.2f')
        print(f'pUnitario: {pUnitario}')

        ## Valor Venta
        valorV = root.find('.//cac:DebitNoteLine//cac:Price//cbc:PriceAmount', namespaces).text
        print(f'valorV: {valorV}')
        
        ## Op Gravada
        opGravada = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxableAmount', namespaces).text
        print(f'opGravada; {opGravada}')

        porcentaje = root.find('.//cac:TaxTotal//cac:TaxCategory//cbc:Percent', namespaces).text
        porcentaje = f"{porcentaje[:2]}%"

        igv = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxAmount', namespaces).text
        igv = format(float(igv), '.2f')
        print(f'igv: {igv}')

        total = root.find('.//cac:RequestedMonetaryTotal//cbc:PayableAmount', namespaces).text
        total = format(float(total), '.2f')
        print(f'total: {total}')

        # Numero en texto
        # Numero en texto
        numeroTexto = root.find('cbc:Note', namespaces)
        
        numeroTexto = numeroTexto.text if numeroTexto is not None else self.numerosTexto.get(total)

        # Observaciones
        ## Invocar función para cargar el archivo con las observaciones, caso que no esté
        ## se busca el archivo y se descomprime
        treeR = self.cargar_observaciones_xml(archivo)
        rootR = treeR.getroot()
        observaciones = rootR.find('.//cac:DocumentResponse//cbc:Description', namespaces).text
        print(f'observaciones: {observaciones}')
        
        # R.U.C
        ruc = root.find('cac:Signature//cac:SignatoryParty//cbc:ID', namespaces)
        ruc = ruc.text if ruc is not None else '20517252558'
        ruc = f'{ruc}-{doc}'
        
        self.datos_formulario = {'fecha': fechaEmision, 'nombre': nombre, 'doc': doc, 'documento': documento, 'direccion': direccion, 'motivo': motivo, 'documento_referencia': documento_referencia, 'item': item, 'codigo': codigo, 
                                'descripcion': desc, 'und': und, 'cantidad': cantidad, 'vUnitario': vUnitario, 'pUnitario': pUnitario, 
                                'valorV': valorV, 'numeroTexto': numeroTexto, 'opGravada': opGravada, 'igv': igv, 'total': total, 'observacionesSunat': observaciones,
                                'hash': hash, 'ruc': ruc}
    
    def procesar_nota_credito(self, root, archivo):
        # Definir el namespace para cbc y cac
        namespaces = {
            'xmlns': "urn:oasis:names:specification:ubl:schema:xsd:CreditNote-2",
            'biz': "urn:bizlinks:names:specification:ubl:peru:schema:xsd:BizlinksAggregateComponents-1",
            'cac': "urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2",
            'cbc': "urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2",
            'ds': "http://www.w3.org/2000/09/xmldsig#",
            'ext': "urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
            'qdt': "urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
            'sac': "urn:sunat:names:specification:ubl:peru:schema:xsd:SunatAggregateComponents-1"
        }
        # Fecha y Hora
        date = root.find("cbc:IssueDate", namespaces).text
        time = root.find("cbc:IssueTime", namespaces).text
        # datetime.strptime(date.text, '%Y-%m-%d')
        fechaEmision = f"{date} {time}"
        print(f"Fecha emision: {fechaEmision}")

        # Código Hash
        hash = root.find('.//ds:DigestValue', namespaces).text
        print(f"hash: {hash}")

        # Nombre
        ## Buscar el valor de cbc:RegistrationName dentro de cac:AccountingCustomerParty
        nombre = root.find('.//cac:AccountingCustomerParty//cbc:RegistrationName', namespaces).text

        print(f'nombre: {nombre}') 
        
            
        # DNI
        documento = root.find('.//cac:AccountingCustomerParty//cbc:ID', namespaces).text
        print (f'documento: {documento}')
        doc = root.find('cbc:ID', namespaces)
        doc = doc.text
        print(f'doc: {doc}')
        
        # MOTIVO
        motivo = root.find('cac:DiscrepancyResponse//cbc:Description', namespaces).text
        print(f'motivo: {motivo}')
        
        #DOCUMENTO REFERENCIA
        documento_referencia = root.find('cac:BillingReference//cbc:ID', namespaces).text
        print(f'documento_referencia: {documento_referencia}')
        
        # Direccion
        direccion = root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces).text if root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces) is not None else '-'
        print(f'direccion: {direccion}')
        
        # Items
        ## Item
        item = root.find('.//cac:CreditNoteLine//cbc:ID', namespaces).text
        print(item)

        ## Código
        codigo = root.find('.//cac:CreditNoteLine//cac:Item//cbc:ID', namespaces)
        codigo = codigo.text if codigo is not None else item
        print(codigo)

        ## Descripción
        desc = root.find('.//cac:CreditNoteLine//cac:Item//cbc:Description', namespaces).text

        ## Und.
        und = root.find('.//cac:CreditNoteLine//cbc:CreditedQuantity', namespaces)
        und = und.attrib.get('unitCode')
        print(f'und: {und}')

        ## Cantidad
        cantidad = root.find('.//cac:CreditNoteLine//cbc:CreditedQuantity', namespaces).text
        cantidad = format(float(cantidad), '.2f')
        print(f'cantidad: {cantidad}')

        ## V. Unitario
        vUnitario = root.find('.//cac:CreditNoteLine//cbc:LineExtensionAmount', namespaces).text
        vUnitario = format(float(vUnitario), '.4f')
        print(f'vUnitario: {vUnitario}')

        ## P. Unitario
        pUnitario = root.find('.//cac:CreditNoteLine//cac:PricingReference//cbc:PriceAmount', namespaces).text
        pUnitario = format(float(pUnitario), '.2f')
        print(f'pUnitario: {pUnitario}')

        ## Valor Venta
        valorV = root.find('.//cac:CreditNoteLine//cac:Price//cbc:PriceAmount', namespaces).text
        print(f'valorV: {valorV}')
        
        ## Op Gravada
        opGravada = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxableAmount', namespaces).text
        print(f'opGravada; {opGravada}')

        porcentaje = root.find('.//cac:TaxTotal//cac:TaxCategory//cbc:Percent', namespaces).text
        porcentaje = f"{porcentaje[:2]}%"

        igv = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxAmount', namespaces).text
        igv = format(float(igv), '.2f')
        print(f'igv: {igv}')

        total = root.find('.//cac:LegalMonetaryTotal//cbc:PayableAmount', namespaces).text
        total = format(float(total), '.2f')
        print(f'total: {total}')

        # Numero en texto
        # Numero en texto
        numeroTexto = root.find('cbc:Note', namespaces)
        
        numeroTexto = numeroTexto.text if numeroTexto is not None else self.numerosTexto.get(total)

        # Observaciones
        ## Invocar función para cargar el archivo con las observaciones, caso que no esté
        ## se busca el archivo y se descomprime
        treeR = self.cargar_observaciones_xml(archivo)
        rootR = treeR.getroot()
        observaciones = rootR.find('.//cac:DocumentResponse//cbc:Description', namespaces).text
        print(f'observaciones: {observaciones}')
        
        # R.U.C
        ruc = root.find('cac:Signature//cac:SignatoryParty//cbc:ID', namespaces)
        ruc = ruc.text if ruc is not None else '20517252558'
        ruc = f'{ruc}-{doc}'
        
        self.datos_formulario = {'fecha': fechaEmision, 'nombre': nombre, 'doc': doc, 'documento': documento, 'direccion': direccion, 'motivo': motivo, 'documento_referencia': documento_referencia, 'item': item, 'codigo': codigo, 
                                'descripcion': desc, 'und': und, 'cantidad': cantidad, 'vUnitario': vUnitario, 'pUnitario': pUnitario, 
                                'valorV': valorV, 'numeroTexto': numeroTexto, 'opGravada': opGravada, 'igv': igv, 'total': total, 'observacionesSunat': observaciones,
                                'hash': hash, 'ruc': ruc}
    
    def procesar_factura(self, root, archivo):
        # Definir el namespace para cbc y cac
        namespaces = {
            'xmlns': "urn:oasis:names:specification:ubl:schema:xsd:Invoice-2",
            'biz': "urn:bizlinks:names:specification:ubl:peru:schema:xsd:BizlinksAggregateComponents-1",
            'cac': "urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2",
            'cbc': "urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2",
            'ds': "http://www.w3.org/2000/09/xmldsig#",
            'ext': "urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
            'qdt': "urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
            'sac': "urn:sunat:names:specification:ubl:peru:schema:xsd:SunatAggregateComponents-1"
        }
        
        # Fecha y Hora
        date = root.find("cbc:IssueDate", namespaces).text
        time = root.find("cbc:IssueTime", namespaces).text
        # datetime.strptime(date.text, '%Y-%m-%d')
        fechaEmision = f"{date} {time}"
        print(f"Fecha emision: {fechaEmision}")

        # Código Hash
        hash = root.find('.//ds:DigestValue', namespaces).text
        print(f"hash: {hash}")

        # Nombre
        ## Buscar el valor de cbc:RegistrationName dentro de cac:AccountingCustomerParty
        nombre = root.find('.//cac:AccountingCustomerParty//cbc:RegistrationName', namespaces).text

        print(f'nombre: {nombre}') 
            
        # DNI
        documento = root.find('.//cac:AccountingCustomerParty//cbc:ID', namespaces).text
        print (f'documento: {documento}')
        # Documento boleta, factura etc
        doc = root.find('cbc:ID', namespaces)
        doc = doc.text
        print(f'doc: {doc}')
        
        # Direccion
        direccion = root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces).text if root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces) is not None else '-'
        print(f'direccion: {direccion}')
        
        # Forma de pago
        forma_pago = root.find('cac:PaymentTerms//cbc:PaymentMeansID', namespaces)
        forma_pago = forma_pago.text if forma_pago is not None else "Contado"
        print(f'forma_pago: {forma_pago}')
        
        # Items
        ## Item
        item = root.find('.//cac:InvoiceLine//cbc:ID', namespaces).text
        print(item)

        ## Código
        codigo = root.find('.//cac:InvoiceLine//cac:Item//cbc:ID', namespaces)
        codigo = codigo.text if codigo is not None else item
        print(codigo)

        ## Descripción
        desc = root.find('.//cac:InvoiceLine//cac:Item//cbc:Description', namespaces).text

        ## Und.
        und = root.find('.//cac:InvoiceLine//cbc:InvoicedQuantity', namespaces)
        und = und.attrib.get('unitCode')
        print(f'und: {und}')

        ## Cantidad
        cantidad = root.find('.//cac:InvoiceLine//cbc:InvoicedQuantity', namespaces).text
        cantidad = format(float(cantidad), '.2f')
        print(f'cantidad: {cantidad}')

        ## V. Unitario
        vUnitario = root.find('.//cac:InvoiceLine//cbc:LineExtensionAmount', namespaces).text
        vUnitario = format(float(vUnitario), '.4f')
        print(f'vUnitario: {vUnitario}')

        ## P. Unitario
        pUnitario = root.find('.//cac:InvoiceLine//cac:PricingReference//cbc:PriceAmount', namespaces).text
        pUnitario = format(float(pUnitario), '.2f')
        print(f'pUnitario: {pUnitario}')

        ## Valor Venta
        valorV = root.find('.//cac:InvoiceLine//cac:Price//cbc:PriceAmount', namespaces).text
        print(f'valorV: {valorV}')
        # Moneda
        opGravada = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxableAmount', namespaces).text
        print(f'opGravada; {opGravada}')

        # porcentaje = root.find('.//cac:TaxTotal//cac:TaxCategory//cbc:Percent', namespaces).text
        # porcentaje = f"{porcentaje[:2]}%"

        igv = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxAmount', namespaces).text
        igv = format(float(igv), '.2f')
        print(f'igv: {igv}')

        total = root.find('.//cac:LegalMonetaryTotal//cbc:PayableAmount', namespaces).text
        total = format(float(total), '.2f')
        print(f'total: {total}')

        # Numero en texto
        numeroTexto = root.find('cbc:Note', namespaces)
        
        numeroTexto = numeroTexto.text if numeroTexto is not None else self.numerosTexto.get(total)

        # Observaciones
        ## Invocar función para cargar el archivo con las observaciones, caso que no esté
        ## se busca el archivo y se descomprime
        treeR = self.cargar_observaciones_xml(archivo)
        
        if treeR != None:
            rootR = treeR.getroot()
            observaciones = rootR.find('.//cac:DocumentResponse//cbc:Description', namespaces).text
            print(f'observaciones: {observaciones}')
        else:
            observaciones = '0'
        
        # Informacion Adicional
        additional_properties = root.findall('.//ext:ExtensionContent//biz:AdditionalProperty', namespaces)
            
        additional_data = []
        direccionSucursal = self.peaje_nombres.get(doc[1]) if self.peaje_nombres.get(doc[1]) != None else '0'
        observacion = 'MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA'
        placa = '0'
        comentario = '0'
        nota_detracciones = '0'
        
        for prop in additional_properties:
            id_value = prop.find('cbc:ID', namespaces).text
            value = prop.find('cbc:Value', namespaces).text
            additional_data.append({'ID': id_value, 'Value': value})
            
        for i in additional_data:
            id_value = int(i['ID'])
            value = i['Value']
            
            # Direccion de la Sucursal
            if id_value == 9785:
                direccionSucursal = value if value is not None else direccionSucursal
            # Placa
            elif id_value == 9114:
                placa = value
            # Observación
            elif id_value == 9618:
                observacion = value if value != 'MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA' else observacion
            # Comentario
            elif id_value == 9510:
                comentario = value
            # Nota - Defracciones
            elif id_value == 9752:
                nota_detracciones = value
            
        print(placa)
        print(direccionSucursal)
        print(observacion)
        print(f'comentario: {comentario}')
        print(f'nota_detracciones: {nota_detracciones}')
        
        # R.U.C
        ruc = root.find('cac:Signature//cac:SignatoryParty//cbc:ID', namespaces)
        ruc = ruc.text if ruc is not None else '20517252558'
        ruc = f'{ruc}-{doc}'
        
        self.datos_formulario = {'fecha': fechaEmision, 'nombre': nombre, 'doc': doc, 'documento': documento, 'direccion': direccion, 'forma_pago': forma_pago, 'item': item, 'codigo': codigo, 
                                'descripcion': desc, 'und': und, 'cantidad': cantidad, 'vUnitario': vUnitario, 'pUnitario': pUnitario, 
                                'valorV': valorV, 'numeroTexto': numeroTexto, 'opGravada': opGravada, 'igv': igv, 'total': total, 'observacionesSunat': observaciones,
                                'direccionSucursal': direccionSucursal, 'observacion': observacion, 'comentario': comentario, 'nota_detracciones': nota_detracciones, 'placa': placa, 'hash': hash, 'ruc': ruc}

    def procesar_boleta(self, root, archivo):
        namespaces = {
            'xmlns': "urn:oasis:names:specification:ubl:schema:xsd:Invoice-2",
            'biz': "urn:bizlinks:names:specification:ubl:peru:schema:xsd:BizlinksAggregateComponents-1",
            'cac': "urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2",
            'cbc': "urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2",
            'ds': "http://www.w3.org/2000/09/xmldsig#",
            'ext': "urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
            'qdt': "urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
            'sac': "urn:sunat:names:specification:ubl:peru:schema:xsd:SunatAggregateComponents-1"
        }
        
        # Fecha y Hora
        date = root.find("cbc:IssueDate", namespaces).text
        time = root.find("cbc:IssueTime", namespaces)
        
        # datetime.strptime(date.text, '%Y-%m-%d')
        if time is not None:
            time = time.text
            fechaEmision = f"{date} {time}"
        else:
            fechaEmision = f"{date}"
            
        print(f"Fecha emision: {fechaEmision}")

        # Código Hash
        hash = root.find('.//ds:DigestValue', namespaces).text
        print(f"hash: {hash}")

        # Nombre
        ## Buscar el valor de cbc:RegistrationName dentro de cac:AccountingCustomerParty
        nombre = root.find('.//cac:AccountingCustomerParty//cbc:RegistrationName', namespaces).text

        print(f'nombre: {nombre}') 
        
            
        # DNI
        documento = root.find('.//cac:AccountingCustomerParty//cbc:ID', namespaces).text
        print (f'documento: {documento}')
        # Documento boleta, factura etc
        doc = root.find('cbc:ID', namespaces)
        doc = doc.text
        print(f'doc: {doc}')
        
        # Direccion
        direccion = root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces).text if root.find('cac:AccountingCustomerParty//cac:AddressLine//cbc:Line',namespaces) is not None else '-'
        print(f'direccion: {direccion}')
        
        # Items
        ## Item
        item = root.find('.//cac:InvoiceLine//cbc:ID', namespaces).text
        print(item)

        ## Código
        codigo = root.find('.//cac:InvoiceLine//cac:Item//cbc:ID', namespaces)
        codigo = codigo.text if codigo is not None else item
        print(codigo)

        ## Descripción
        desc = root.find('.//cac:InvoiceLine//cac:Item//cbc:Description', namespaces).text

        ## Und.
        und = root.find('.//cac:InvoiceLine//cbc:InvoicedQuantity', namespaces)
        und = und.attrib.get('unitCode')
        print(f'und: {und}')

        ## Cantidad
        cantidad = root.find('.//cac:InvoiceLine//cbc:InvoicedQuantity', namespaces).text
        cantidad = format(float(cantidad), '.2f')
        print(f'cantidad: {cantidad}')

        ## V. Unitario
        vUnitario = root.find('.//cac:InvoiceLine//cbc:LineExtensionAmount', namespaces).text
        vUnitario = format(float(vUnitario), '.4f')
        print(f'vUnitario: {vUnitario}')

        ## P. Unitario
        pUnitario = root.find('.//cac:InvoiceLine//cac:PricingReference//cbc:PriceAmount', namespaces).text
        pUnitario = format(float(pUnitario), '.2f')
        print(f'pUnitario: {pUnitario}')

        ## Valor Venta
        valorV = root.find('.//cac:InvoiceLine//cac:Price//cbc:PriceAmount', namespaces).text
        print(f'valorV: {valorV}')
        # Moneda
        opGravada = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxableAmount', namespaces).text
        print(f'opGravada; {opGravada}')

        porcentaje = root.find('.//cac:TaxTotal//cac:TaxCategory//cbc:Percent', namespaces).text
        porcentaje = f"{porcentaje[:2]}%"

        igv = root.find('.//cac:TaxTotal//cac:TaxSubtotal//cbc:TaxAmount', namespaces).text
        igv = format(float(igv), '.2f')
        print(f'igv: {igv}')

        total = root.find('.//cac:LegalMonetaryTotal//cbc:PayableAmount', namespaces).text
        total = format(float(total), '.2f')
        print(f'total: {total}')

        # Numero en texto
        # Numero en texto
        numeroTexto = root.find('cbc:Note', namespaces)
        
        numeroTexto = numeroTexto.text if numeroTexto is not None else self.numerosTexto.get(total)

        # Observaciones
        ## Invocar función para cargar el archivo con las observaciones, caso que no esté
        ## se busca el archivo y se descomprime
        treeR = self.cargar_observaciones_xml(archivo)
        rootR = treeR.getroot()
        observaciones = rootR.find('.//cac:DocumentResponse//cbc:Description', namespaces).text
        print(f'observaciones: {observaciones}')
        
        # Informacion Adicional
        additional_properties = root.findall('.//ext:ExtensionContent//biz:AdditionalProperty', namespaces)
        additional_data = []
        direccionSucursal = self.peaje_nombres.get(doc[1])
        observacion = 'MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA'
        placa = '0'
        
        for prop in additional_properties:
            id_value = prop.find('cbc:ID', namespaces).text
            value = prop.find('cbc:Value', namespaces).text
            additional_data.append({'ID': id_value, 'Value': value})
            
        for i in additional_data:
            id_value = int(i['ID'])
            value = i['Value']
            
            # Direccion de la Sucursal
            if id_value == 9785:
                direccionSucursal = value if value is not None else direccionSucursal
            # Placa
            elif id_value == 9114:
                placa = value
            # Observación
            elif id_value == 9618:
                observacion = value if value != 'MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA' else observacion
                
        print(placa)
        print(direccionSucursal)
        print(observacion)
        
        # R.U.C
        ruc = root.find('cac:Signature//cac:SignatoryParty//cbc:ID', namespaces)
        ruc = ruc.text if ruc is not None else '20517252558'
        ruc = f'{ruc}-{doc}'
        
        self.datos_formulario = {'fecha': fechaEmision, 'nombre': nombre, 'doc': doc, 'documento': documento, 'direccion': direccion, 'item': item, 'codigo': codigo, 
                                'descripcion': desc, 'und': und, 'cantidad': cantidad, 'vUnitario': vUnitario, 'pUnitario': pUnitario, 
                                'valorV': valorV, 'numeroTexto': numeroTexto, 'opGravada': opGravada, 'igv': igv, 'total': total, 'observacionesSunat': observaciones,
                                'direccionSucursal': direccionSucursal, 'observacion': observacion, 'placa': placa, 'hash': hash, 'ruc': ruc}
    
    def cargar_observaciones_xml(self, archivo):
        archivo_ruta = Path(archivo)  # Convertir a objeto Path para manejar rutas
        archivoR = f"R-{archivo_ruta.stem}"

        # Obtener la ruta base del archivo
        carpeta_base = archivo_ruta.parent

        # Construir la ruta completa hacia la carpeta y el archivo XML asociado
        ruta_completa_archivoR = carpeta_base / archivoR / f"{archivoR}.xml"

        try:
            # Intentar cargar el archivo XML
            treeR = ET.parse(ruta_completa_archivoR)
            print(f"Archivo XML encontrado y cargado: {ruta_completa_archivoR}")
            return treeR
        except FileNotFoundError:
            print(f"No se encontró el archivo XML en {ruta_completa_archivoR}, buscando archivo comprimido...")

            # Si no se encuentra el archivo XML, buscar un archivo comprimido en la misma carpeta
            archivo_zip = carpeta_base / f"{archivoR}.zip"
            archivo_xml = carpeta_base / f"{archivoR}.xml"
            if archivo_xml.exists():
                treeR = ET.parse(archivo_xml)
                print(f"Archivo XML encontrado y cargado: {archivo_xml}")
                return treeR
            if archivo_zip.exists():
                print(f"Archivo comprimido encontrado: {archivo_zip}")
                
                # Crear una carpeta para descomprimir
                carpeta_destino = carpeta_base / archivoR
                os.makedirs(carpeta_destino, exist_ok=True)

                # Descomprimir el archivo ZIP
                with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
                    zip_ref.extractall(carpeta_destino)

                # Intentar cargar el archivo XML descomprimido
                ruta_completa_archivoR = carpeta_destino / f"{archivoR}.xml"
                try:
                    treeR = ET.parse(ruta_completa_archivoR)
                    print(f"Archivo XML descomprimido y cargado: {ruta_completa_archivoR}")
                    return treeR
                except FileNotFoundError:
                    print(f"No se pudo encontrar el archivo XML dentro del archivo descomprimido: {ruta_completa_archivoR}")
                    return None
            else:
                print(f"No se encontró ningún archivo comprimido con el nombre {archivoR}.zip en {carpeta_base}")
                return None
    
    def ventana_carpeta_generada(self, ruta_archivo):
        
        # Especificar el tamaño de la ventana
        ancho_ventana = 200
        alto_ventana = 100
        
        # Crear una nueva ventana
        ventana = Toplevel(self.root)
        ventana.title("Abrir carpeta")
        
        # Establecer el tamaño de la ventana
        ventana.geometry(f"{ancho_ventana}x{alto_ventana}")

        etiqueta = Label(ventana, text="¿Desea abrir la carpeta generada?")
        etiqueta.grid(row=0, column=0, columnspan=2, padx=10, pady=10, sticky="we")
        
        # Botón para confirmar apertura del archivo
        boton_confirmar = ttk.Button(ventana, text="Sí", command=lambda: self.confirmar_abrir_archivo(ventana, ruta_archivo))
        boton_confirmar.grid(row=1, column=0, padx=10, pady=10, sticky="we")
        
        # Botón para cancelar (cerrar la ventana sin abrir el archivo)
        boton_cancelar = ttk.Button(ventana, text="No", command=ventana.destroy)
        boton_cancelar.grid(row=1, column=1, padx=10, pady=10, sticky="we")
        
        # Vincular la tecla Enter al botón de confirmación
        ventana.bind('<Return>', lambda event: boton_confirmar.invoke())
        # Vincular la tecla Esc para cerrar la ventana
        ventana.bind('<Escape>', lambda event: ventana.destroy())
        
        # Centrar ventana
        self.centrar_ventana(ventana, ancho_ventana, alto_ventana)
    
    def confirmar_abrir_archivo(self, ventana, ruta_archivo):
        # Obtener la carpeta del archivo
        carpeta = os.path.dirname(ruta_archivo)
        
        # Abrir la carpeta 
        try:
            os.startfile(f'{os.getcwd()}{carpeta}')
        except Exception as e:
            print(f"No se pudo abrir la carpeta:")
            print(e)
        
        # Cerrar la ventana
        ventana.destroy()

# %%
# Iniciar programa                
                
root = Tk()
Xml_a_pdf(root)
root.mainloop()
# Out:
# Archivos seleccionados: 2874
# Fecha emision: 2019-01-09 13:14:49
# hash: 0QSSOhAd+ipnEAYnnUCocu/iIFU=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F111-00038175
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00038175\R-20517252558-01-F111-00038175.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00038175.xml
# observaciones: La Factura numero F111-00038175, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-04-30 11:37:03
# hash: HDFXdF+0jXKP4Ta+kI0WrATlSvQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F111-00082303
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00082303\R-20517252558-01-F111-00082303.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00082303.xml
# observaciones: La Factura numero F111-00082303, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-09-11 10:08:20
# hash: AACw07jJ25r1hvQbZqe2Ex4Wt20=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F111-00131395
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00131395\R-20517252558-01-F111-00131395.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F111-00131395.xml
# observaciones: El comprobante numero F111-00131395, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-28 16:45:20
# hash: 8LLwi9ixz8GBs5D4J1pVEig7bhI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F112-00019816
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00019816\R-20517252558-01-F112-00019816.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00019816.xml
# observaciones: La Factura numero F112-00019816, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-03-09 12:54:08
# hash: 443hD6nILy3vbPaY+Go9aehPt3A=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F112-00027120
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00027120\R-20517252558-01-F112-00027120.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00027120.xml
# observaciones: La Factura numero F112-00027120, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-27 07:49:54
# hash: IgFVpWPMa3ulSUjku6x+m7Lclpo=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F112-00076904
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00076904\R-20517252558-01-F112-00076904.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F112-00076904.xml
# observaciones: El comprobante numero F112-00076904, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 15:10:42
# hash: XkJjdolCdcFHPtRPHG9NaEqEnxg=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F113-00010819
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00010819\R-20517252558-01-F113-00010819.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00010819.xml
# observaciones: La Factura numero F113-00010819, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 09:24:13
# hash: 5wPbPg2BSLURQ9vl5SHpeyoKMhI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F113-00010933
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00010933\R-20517252558-01-F113-00010933.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00010933.xml
# observaciones: La Factura numero F113-00010933, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-28 18:58:56
# hash: 6AECzDr9Wwprr0NI/gXqW2jJ9kk=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F113-00013324
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00013324\R-20517252558-01-F113-00013324.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00013324.xml
# observaciones: La Factura numero F113-00013324, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-06-13 09:13:18
# hash: G4qFy64kSodAZBN/yWhkOLAVQ0I=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F113-00029356
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00029356\R-20517252558-01-F113-00029356.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00029356.xml
# observaciones: La Factura numero F113-00029356, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-09-11 11:03:38
# hash: Q+oyX67MbErUMq7h4LrDvLc65QQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F113-00040367
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00040367\R-20517252558-01-F113-00040367.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F113-00040367.xml
# observaciones: El comprobante numero F113-00040367, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-04-30 11:58:43
# hash: kdwBZy7M94bsV/S89qqhhnRA7rs=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F114-00095121
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00095121\R-20517252558-01-F114-00095121.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00095121.xml
# observaciones: La Factura numero F114-00095121, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-21 13:17:12
# hash: FTph/CDpsLyzpvh1Y1N5ChSqnag=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F114-00188601
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00188601\R-20517252558-01-F114-00188601.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00188601.xml
# observaciones: El comprobante numero F114-00188601, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-27 11:56:09
# hash: GbyR8Q5CiW7rQwssMhM1hLx7DUw=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F114-00191207
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00191207\R-20517252558-01-F114-00191207.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F114-00191207.xml
# observaciones: El comprobante numero F114-00191207, ha sido aceptada
# 0
# Matarani
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2018-11-01 05:56:28
# hash: dozFq9+xiddNQn3URLuOzw2P3pc=
# nombre: AUGUSTO RIVEROS MUÑOZ
# documento: 10295402739
# doc: F211-00014320
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 6.7800
# pUnitario: 8.00
# valorV: 6.78
# opGravada; 6.78
# igv: 1.22
# total: 8.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00014320\R-20517252558-01-F211-00014320.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00014320.xml
# observaciones: La Factura numero F211-00014320, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-01 08:08:40
# hash: wXBRER4+ocjwNmYp3/kcKYEYG9c=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00064992
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00064992\R-20517252558-01-F211-00064992.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00064992.xml
# observaciones: La Factura numero F211-00064992, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-01 16:43:32
# hash: kvFODatckUICimm8M+DHWlhFACI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065180
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065180\R-20517252558-01-F211-00065180.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065180.xml
# observaciones: La Factura numero F211-00065180, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 04:23:18
# hash: qMknVxuX4q+0gkUwJYj93rTO6C4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065334
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065334\R-20517252558-01-F211-00065334.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065334.xml
# observaciones: La Factura numero F211-00065334, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 09:06:14
# hash: kdB47A7D0HyUtol+kZqUvSaZD9Q=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065549
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065549\R-20517252558-01-F211-00065549.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065549.xml
# observaciones: La Factura numero F211-00065549, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 12:36:33
# hash: sJlg0co/FIdZ2Fimvtk3ghatCKA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065716
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065716\R-20517252558-01-F211-00065716.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065716.xml
# observaciones: La Factura numero F211-00065716, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 12:48:34
# hash: dZzlXnanNg/ONbdxvBcDmXejb90=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065731
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065731\R-20517252558-01-F211-00065731.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065731.xml
# observaciones: La Factura numero F211-00065731, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 15:59:56
# hash: Z5Zt1nzNqlmc5UuCHbxk6qRunjo=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00065939
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065939\R-20517252558-01-F211-00065939.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00065939.xml
# observaciones: La Factura numero F211-00065939, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-02 19:15:27
# hash: NdZsg34XIKOaGjR/OzOt4slQBVk=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00066091
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00066091\R-20517252558-01-F211-00066091.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00066091.xml
# observaciones: La Factura numero F211-00066091, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-03 01:35:35
# hash: HXcNDaOIpkeLP3OLrJBJB5BC1XM=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00066229
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00066229\R-20517252558-01-F211-00066229.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00066229.xml
# observaciones: La Factura numero F211-00066229, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-03 19:21:50
# hash: fpnhkuaBc+2fztVaNr1V/zzK3pQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00067107
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00067107\R-20517252558-01-F211-00067107.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00067107.xml
# observaciones: La Factura numero F211-00067107, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-03 20:32:11
# hash: qvEwJrDi4lDf5lkxEc7bt4WKy1E=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00067148
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00067148\R-20517252558-01-F211-00067148.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00067148.xml
# observaciones: La Factura numero F211-00067148, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-05 22:22:42
# hash: C6FYM22rflbC2DOYKHK4c+jebT0=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069037
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069037\R-20517252558-01-F211-00069037.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069037.xml
# observaciones: La Factura numero F211-00069037, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-06 11:53:14
# hash: FoSWwqsJyv5Wdk2/V1oDcRq30IA=
# nombre: NEGOCIOS PARAGU E.I.R.L.
# documento: 20455408041
# doc: F211-00069296
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 20.3400
# pUnitario: 24.00
# valorV: 20.34
# opGravada; 20.34
# igv: 3.66
# total: 24.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069296\R-20517252558-01-F211-00069296.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069296.xml
# observaciones: La Factura numero F211-00069296, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-06 16:52:54
# hash: YCttw9IVgSOVy89m4O+UduKsqpA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069476
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069476\R-20517252558-01-F211-00069476.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069476.xml
# observaciones: La Factura numero F211-00069476, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-06 16:59:16
# hash: u23/3osU5/8LDFpaCPNECYSOMeA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069479
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069479\R-20517252558-01-F211-00069479.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069479.xml
# observaciones: La Factura numero F211-00069479, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-06 21:41:01
# hash: 4Qi9fIP6dprPLhFIQOPvci9zt8E=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069532
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069532\R-20517252558-01-F211-00069532.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069532.xml
# observaciones: La Factura numero F211-00069532, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-06 22:50:25
# hash: zcNqXRVuua1lupqf3Fbe5Wg5lj0=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069565
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069565\R-20517252558-01-F211-00069565.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069565.xml
# observaciones: La Factura numero F211-00069565, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 03:22:40
# hash: jFgLJu2xxkxG/1X+j+4RKrO/yno=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069604
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069604\R-20517252558-01-F211-00069604.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069604.xml
# observaciones: La Factura numero F211-00069604, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 06:57:31
# hash: vfPywyeIbIbO7i0sx3pSWJDPyO0=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00069763
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069763\R-20517252558-01-F211-00069763.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00069763.xml
# observaciones: La Factura numero F211-00069763, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 12:55:59
# hash: Z3YZJZX+pNxO8MaS+UF0+AorC7s=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00070035
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070035\R-20517252558-01-F211-00070035.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070035.xml
# observaciones: La Factura numero F211-00070035, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 16:14:40
# hash: a8gLOsMmcj8ZNSdpnKXv0diTHjA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00070207
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070207\R-20517252558-01-F211-00070207.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070207.xml
# observaciones: La Factura numero F211-00070207, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 16:40:27
# hash: fFtat739Cm14QRlrOMNCVBDNB7E=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00070233
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070233\R-20517252558-01-F211-00070233.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070233.xml
# observaciones: La Factura numero F211-00070233, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-07 17:15:58
# hash: j8FIAnawvXQg2uaic3yt9qfTfPw=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00070267
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070267\R-20517252558-01-F211-00070267.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070267.xml
# observaciones: La Factura numero F211-00070267, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-08 07:25:27
# hash: Xkjb197mev3xkkFc3+IfjwC3TFw=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00070751
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070751\R-20517252558-01-F211-00070751.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00070751.xml
# observaciones: La Factura numero F211-00070751, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-08 19:53:47
# hash: /IiFAHEWQSWj95kNjiySprk10yM=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00071345
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071345\R-20517252558-01-F211-00071345.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071345.xml
# observaciones: La Factura numero F211-00071345, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 07:34:16
# hash: qiycIG1gAZ0ffQO0FAnSIaLQW4A=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00071677
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071677\R-20517252558-01-F211-00071677.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071677.xml
# observaciones: La Factura numero F211-00071677, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 08:02:25
# hash: rGMFQk4m4SRQzGit36VeI8FBpLI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00071701
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071701\R-20517252558-01-F211-00071701.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00071701.xml
# observaciones: La Factura numero F211-00071701, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 14:58:28
# hash: inQ/JKANsqEBYHpsqZ1lG+cKPh4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00072048
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072048\R-20517252558-01-F211-00072048.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072048.xml
# observaciones: La Factura numero F211-00072048, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 16:53:45
# hash: MESXhD3TQAN8bV7XDJoNVK18e6g=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00072118
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072118\R-20517252558-01-F211-00072118.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072118.xml
# observaciones: La Factura numero F211-00072118, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-09 19:59:21
# hash: 0p5raLTFpB+DyzNc2iTLs5q84BM=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00072245
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072245\R-20517252558-01-F211-00072245.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072245.xml
# observaciones: La Factura numero F211-00072245, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 02:05:55
# hash: ZSWQtOZxlxpA0gUSLASV7+HSz9o=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00072372
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072372\R-20517252558-01-F211-00072372.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072372.xml
# observaciones: La Factura numero F211-00072372, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 05:40:35
# hash: izkHY7mgB2JDt7VPuWgiDXksFDw=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00072442
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072442\R-20517252558-01-F211-00072442.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00072442.xml
# observaciones: La Factura numero F211-00072442, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 19:47:35
# hash: hzvwvBPhgoVGU61FoaWjAYj51yA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00073070
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00073070\R-20517252558-01-F211-00073070.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00073070.xml
# observaciones: La Factura numero F211-00073070, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-11 15:27:57
# hash: /enL4ZiqkcdSKFRIQtiC3AmMhBo=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00073803
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00073803\R-20517252558-01-F211-00073803.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00073803.xml
# observaciones: La Factura numero F211-00073803, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-12 16:51:21
# hash: DCcrk8MfeqMgnYcwPyP94TI3YiU=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00074817
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00074817\R-20517252558-01-F211-00074817.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00074817.xml
# observaciones: La Factura numero F211-00074817, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-13 16:54:11
# hash: lRl+A7smAnFcp/GiO23Gm6jGhmY=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00075442
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075442\R-20517252558-01-F211-00075442.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075442.xml
# observaciones: La Factura numero F211-00075442, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-13 17:01:56
# hash: cLkBeuFDveIDXjDXOYhQpga7Asg=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00075447
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075447\R-20517252558-01-F211-00075447.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075447.xml
# observaciones: La Factura numero F211-00075447, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-13 23:13:44
# hash: MP4MAzj05IM2kKawjd4YSETQ2JU=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00075525
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075525\R-20517252558-01-F211-00075525.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075525.xml
# observaciones: La Factura numero F211-00075525, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-13 23:43:14
# hash: 46N4aO0PJ7zu9iE7cYFlQu/emug=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00075528
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075528\R-20517252558-01-F211-00075528.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00075528.xml
# observaciones: La Factura numero F211-00075528, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-14 15:34:30
# hash: evZoaXhE6rGJQEfBG0SlCTORQr4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00076121
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00076121\R-20517252558-01-F211-00076121.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00076121.xml
# observaciones: La Factura numero F211-00076121, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-14 18:30:27
# hash: n/1MAdYbWqDFMzhoQH87F6w4hMc=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00076277
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00076277\R-20517252558-01-F211-00076277.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00076277.xml
# observaciones: La Factura numero F211-00076277, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-15 19:12:14
# hash: lxrkw3GqMVrmvvz8RvTsxJGUGz4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00077201
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00077201\R-20517252558-01-F211-00077201.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00077201.xml
# observaciones: La Factura numero F211-00077201, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-16 20:30:13
# hash: XTvgn9h3i+hFM0rSucwkE7E3xhQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00078194
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078194\R-20517252558-01-F211-00078194.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078194.xml
# observaciones: La Factura numero F211-00078194, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-16 21:42:58
# hash: RyZ3dpdEDAP9+f7WM7TtrcMDZpY=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00078229
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078229\R-20517252558-01-F211-00078229.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078229.xml
# observaciones: La Factura numero F211-00078229, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-17 10:47:50
# hash: LwYqoV31Nh+L+UryBgUk2u/kMpw=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00078613
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078613\R-20517252558-01-F211-00078613.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078613.xml
# observaciones: La Factura numero F211-00078613, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-17 10:56:34
# hash: qf5AYYUMZs1YysdUbMzrfXcCrT4=
# nombre: CASTILLO ZEVALLOS FELIX
# documento: 10023672494
# doc: F211-00078620
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 20.3400
# pUnitario: 24.00
# valorV: 20.34
# opGravada; 20.34
# igv: 3.66
# total: 24.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078620\R-20517252558-01-F211-00078620.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00078620.xml
# observaciones: La Factura numero F211-00078620, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-19 16:55:04
# hash: Lopjx7gkq8+GwBy9f3Czw9GwZSA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00080619
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080619\R-20517252558-01-F211-00080619.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080619.xml
# observaciones: La Factura numero F211-00080619, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-19 19:49:06
# hash: N/kWg+hJG6Eg31PPS+/yXgXQNvE=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00080723
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080723\R-20517252558-01-F211-00080723.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080723.xml
# observaciones: La Factura numero F211-00080723, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-20 07:40:27
# hash: 69iV5sccwuyUweaonj0rALbGYIo=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00080949
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080949\R-20517252558-01-F211-00080949.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00080949.xml
# observaciones: La Factura numero F211-00080949, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-20 16:41:52
# hash: LR32vHOAKFaZ0U8ywCsUAqht1jc=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00081267
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00081267\R-20517252558-01-F211-00081267.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00081267.xml
# observaciones: La Factura numero F211-00081267, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-20 16:51:26
# hash: /vc79rVBu+DBTMwp9K7tiLqL2gs=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00081277
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00081277\R-20517252558-01-F211-00081277.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00081277.xml
# observaciones: La Factura numero F211-00081277, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-21 16:14:52
# hash: 4bICcMf0HdCMlN2GEnsjO++KPo0=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00082077
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 4.2400
# pUnitario: 5.00
# valorV: 4.24
# opGravada; 4.24
# igv: 0.76
# total: 5.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00082077\R-20517252558-01-F211-00082077.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00082077.xml
# observaciones: La Factura numero F211-00082077, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-21 16:58:35
# hash: S36qLMWUs8D6Xo9WQ+2kzTiKpdE=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F211-00082109
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 10.1700
# pUnitario: 12.00
# valorV: 10.17
# opGravada; 10.17
# igv: 1.83
# total: 12.00
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00082109\R-20517252558-01-F211-00082109.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F211-00082109.xml
# observaciones: La Factura numero F211-00082109, ha sido aceptada
# 0
# Uchumayo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-21 22:52:51
# hash: 2sz5orc9asB5AZ8hP6yWT5huQ3k=
# nombre: OPECOVI  S.A.C.
# ...
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-12-29 18:20:22
# hash: a29p9H4uOf9vugINgIRxnmpYWQ4=
# nombre: OPECOVI S.A.C.
# documento: 20517746046
# doc: F612-00037043
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F612-00037043\R-20517252558-01-F612-00037043.xml, buscando archivo comprimido...
# No se encontró ningún archivo comprimido con el nombre R-20517252558-01-F612-00037043.zip en D:\pdf\PDFEJEMPLO\2019-2020\2019
# 0
# Unidad de Peaje Pampa Cuellar km 65+000 Ruta 34A
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-12-30 16:17:53
# hash: utkXob4vbs6DJU6QxF/MSh+OzRE=
# nombre: OPECOVI S.A.C.
# documento: 20517746046
# doc: F612-00037163
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F612-00037163\R-20517252558-01-F612-00037163.xml, buscando archivo comprimido...
# No se encontró ningún archivo comprimido con el nombre R-20517252558-01-F612-00037163.zip en D:\pdf\PDFEJEMPLO\2019-2020\2019
# 0
# Unidad de Peaje Pampa Cuellar km 65+000 Ruta 34A
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-12-31 12:06:39
# hash: vKpCfA8vaBAB3/qsPMg8ItX5Sjc=
# nombre: OPECOVI S.A.C.
# documento: 20517746046
# doc: F612-00037240
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F612-00037240\R-20517252558-01-F612-00037240.xml, buscando archivo comprimido...
# No se encontró ningún archivo comprimido con el nombre R-20517252558-01-F612-00037240.zip en D:\pdf\PDFEJEMPLO\2019-2020\2019
# 0
# Unidad de Peaje Pampa Cuellar km 65+000 Ruta 34A
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-03 19:37:59
# hash: Bu8scaKscNSCAPW4KhrMq0elvbU=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00015269
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00015269\R-20517252558-01-F711-00015269.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00015269.xml
# observaciones: La Factura numero F711-00015269, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 13:12:54
# hash: uuFC8xzt93pn9JrTncjOzl32o10=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00016501
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00016501\R-20517252558-01-F711-00016501.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00016501.xml
# observaciones: La Factura numero F711-00016501, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-02-13 17:05:46
# hash: +/DWus0f3/iviWm3Ir1JziZ6rGQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00023410
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00023410\R-20517252558-01-F711-00023410.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00023410.xml
# observaciones: La Factura numero F711-00023410, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-02-17 20:17:50
# hash: 7gJRJmpCQPz9TmrqYYhleHVdsrA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00024533
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00024533\R-20517252558-01-F711-00024533.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00024533.xml
# observaciones: La Factura numero F711-00024533, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-04-28 06:52:17
# hash: sMeqAda9aFyCsSNnFfMc9LAjwTA=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00038885
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00038885\R-20517252558-01-F711-00038885.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00038885.xml
# observaciones: La Factura numero F711-00038885, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-06-12 15:14:37
# hash: U8UlHBwG47BrmGMceQERF6pJpX4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00047506
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 3.3100
# pUnitario: 3.90
# valorV: 3.31
# opGravada; 3.31
# igv: 0.59
# total: 3.90
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00047506\R-20517252558-01-F711-00047506.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00047506.xml
# observaciones: La Factura numero F711-00047506, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-10-13 22:32:15
# hash: ZxPGJ6DbhBbWxz0UCGZFGGTMfKY=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00077448
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00077448\R-20517252558-01-F711-00077448.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00077448.xml
# observaciones: El comprobante numero F711-00077448, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-10-13 22:33:48
# hash: MUX88yxaa5wkiwnxbVZdFkQ3gDo=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00077450
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 3.3100
# pUnitario: 3.90
# valorV: 3.31
# opGravada; 3.31
# igv: 0.59
# total: 3.90
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00077450\R-20517252558-01-F711-00077450.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00077450.xml
# observaciones: El comprobante numero F711-00077450, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-20 11:03:31
# hash: 86Apa0e+edL7ynWAbPF5ixcRfHQ=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00087599
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00087599\R-20517252558-01-F711-00087599.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00087599.xml
# observaciones: El comprobante numero F711-00087599, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-20 18:34:09
# hash: L6oRC0OxTbwe3hxnyK2sXCfkly4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F711-00087763
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 3.3100
# pUnitario: 3.90
# valorV: 3.31
# opGravada; 3.31
# igv: 0.59
# total: 3.90
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00087763\R-20517252558-01-F711-00087763.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F711-00087763.xml
# observaciones: El comprobante numero F711-00087763, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-03 20:50:19
# hash: ngkuloVfDyJ4UPUiTlUKzQ9FSzI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00015605
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00015605\R-20517252558-01-F712-00015605.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00015605.xml
# observaciones: La Factura numero F712-00015605, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-01-10 16:25:16
# hash: LuAAatJV3VoMU6jJ/ZFLz1GeVAg=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00016956
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00016956\R-20517252558-01-F712-00016956.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00016956.xml
# observaciones: La Factura numero F712-00016956, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-02-13 18:18:49
# hash: es4ZEkO1VmZ0+HoZBFO0YtfNrC4=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00024309
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00024309\R-20517252558-01-F712-00024309.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00024309.xml
# observaciones: La Factura numero F712-00024309, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-02-17 21:18:04
# hash: /we142iLohumU7LIBZ6biF4lf8k=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00025311
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00025311\R-20517252558-01-F712-00025311.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00025311.xml
# observaciones: La Factura numero F712-00025311, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-04-28 07:59:47
# hash: B6qm5JXgB7w4vETiRIxWzEmLgT0=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00039766
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00039766\R-20517252558-01-F712-00039766.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00039766.xml
# observaciones: La Factura numero F712-00039766, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-10-13 23:18:33
# hash: SSMEGkQA35JIxlfTWt7YgD7HnsI=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00080082
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00080082\R-20517252558-01-F712-00080082.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00080082.xml
# observaciones: El comprobante numero F712-00080082, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-20 11:27:02
# hash: t3HyBn4OEH9IGuWPDsGPT8yZp5s=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00090931
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 3.3100
# pUnitario: 3.90
# valorV: 3.31
# opGravada; 3.31
# igv: 0.59
# total: 3.90
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00090931\R-20517252558-01-F712-00090931.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00090931.xml
# observaciones: El comprobante numero F712-00090931, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Fecha emision: 2019-11-20 11:27:23
# hash: b6pbnDJLz+t6UBkZ3W/yyUbUnLk=
# nombre: OPECOVI  S.A.C.
# documento: 20517746046
# doc: F712-00090932
# direccion: -
# forma_pago: Contado
# 1
# 1
# und: CS
# cantidad: 1.00
# vUnitario: 9.8300
# pUnitario: 11.60
# valorV: 9.83
# opGravada; 9.83
# igv: 1.77
# total: 11.60
# No se encontró el archivo XML en D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00090932\R-20517252558-01-F712-00090932.xml, buscando archivo comprimido...
# Archivo XML encontrado y cargado: D:\pdf\PDFEJEMPLO\2019-2020\2019\R-20517252558-01-F712-00090932.xml
# observaciones: El comprobante numero F712-00090932, ha sido aceptada
# 0
# Ilo
# MANEJE CON CUIDADO SU VIDA ES MUY VALIOSA
# comentario: 0
# nota_detracciones: 0
# Hubo errores en los archivos:
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00258604.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00259114.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00264312.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00270141.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00280185.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F211-00329390.xml
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00229550.xml
#
#
# 20517252558-01-F214-00229550
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00235426.xml
#
#
# 20517252558-01-F214-00235426
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00241151.xml
#
#
# 20517252558-01-F214-00241151
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00260237.xml
#
#
# 20517252558-01-F214-00260237
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00267749.xml
#
#
# 20517252558-01-F214-00267749
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00275114.xml
#
#
# 20517252558-01-F214-00275114
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00275517.xml
#
#
# 20517252558-01-F214-00275517
#
#
# D:\pdf\PDFEJEMPLO\2019-2020\2019\20517252558-01-F214-00324946.xml
#
#
# 20517252558-01-F214-00324946

# %%
from fillpdf import fillpdfs

form_fields = list(fillpdfs.get_form_fields('./plantillas/plantillaNotaDebito.pdf').keys())

i = 0 

valores = []

for field in form_fields:
    valores.append((i, field))
    i+=1

valores
# Out:
# [(0, 'nombre'),
#  (1, 'direccion'),
#  (2, 'item'),
#  (3, 'codigo'),
#  (4, 'descripcion'),
#  (5, 'und'),
#  (6, 'cantidad'),
#  (7, 'pUnitario'),
#  (8, 'vUnitario'),
#  (9, 'opGravada'),
#  (10, 'valorV'),
#  (11, 'total'),
#  (12, 'igv'),
#  (13, 'doc'),
#  (14, 'observacionesSunat'),
#  (15, 'motivo'),
#  (16, 'hash'),
#  (17, 'ruc'),
#  (18, 'fecha'),
#  (19, 'documento_referencia'),
#  (20, 'numeroTexto'),
#  (21, 'documento')]
